# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("CanteenDataSet (Apriori)).csv",header=None)

# %%
df.head()
# Out:
#                                    0
# 0              Tea, Samosa, Sandwich
# 1     Samosa, Tea, Sandwich, Noodles
# 2  Samosa, Cold Coffee, French Fries
# 3           Pizza, Maggie,Samosa,Tea
# 4        Maggie,Cold Coffee,Sandwich

# %%
df = df[0].str.split(',', expand=True)

# %%
df.head()
print(df.shape)
# Out:
# (20, 4)

# %%
records = []
for i in range(1, 20):
    records.append([str(df.values[i, j]) for j in range(0, 4)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
from apyori import apriori

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 51 Relation derived.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({' Cold Coffee', ' French Fries'})
# frozenset({' Maggie', 'Pizza'})
# frozenset({' Maggie', 'Tea'})
# frozenset({' Noodles', ' Sandwich'})
# frozenset({' Tea', ' Noodles'})
# frozenset({' Tea', ' Sandwich'})
# frozenset({'Cold Coffee', 'Maggie'})
# frozenset({'Manchurian', 'Noodles'})
# frozenset({'Tea', 'Pizza'})
# frozenset({' Cold Coffee', 'None', ' French Fries'})
# frozenset({' Cold Coffee', 'Samosa', ' French Fries'})
# frozenset({' Maggie', 'Pizza', 'Samosa'})
# frozenset({' Maggie', 'Tea', 'Pizza'})
# frozenset({' Maggie', 'Tea', 'Samosa'})
# frozenset({' Tea', ' Noodles', ' Sandwich'})
# frozenset({' Noodles', 'Samosa', ' Sandwich'})
# frozenset({' Tea', ' Noodles', 'Samosa'})
# frozenset({' Tea', 'Samosa', ' Sandwich'})
# frozenset({'Black Tea', 'Cold Coffee', 'Noodles'})
# frozenset({'Black Tea', 'Tea', 'Cold Coffee'})
# frozenset({'Fried Maggie', 'French Fries', 'Black Tea'})
# frozenset({'Manchurian', 'Black Tea', 'Noodles'})
# frozenset({'Manchurian', 'Black Tea', 'Sandwich'})
# frozenset({'Black Tea', 'Sandwich', 'Noodles'})
# frozenset({'Black Tea', 'Tea', 'Noodles'})
# frozenset({'None', 'Cold Coffee', 'Maggie'})
# frozenset({'Cold Coffee', 'Maggie', 'Noodles'})
# frozenset({'Pizza', 'Cold Coffee', 'Maggie'})
# frozenset({'Samosa', 'Cold Coffee', 'Maggie'})
# frozenset({'Sandwich', 'Cold Coffee', 'Maggie'})
# frozenset({'Cold Coffee', 'None', 'Noodles'})
# frozenset({'Tea', 'Cold Coffee', 'Noodles'})
# frozenset({'Pizza', 'Cold Coffee', 'Samosa'})
# frozenset({'None', 'Maggie', 'Noodles'})
# frozenset({'Samosa', 'Pizza', 'Maggie'})
# frozenset({'Manchurian', 'Sandwich', 'Noodles'})
# frozenset({'Tea', 'Pizza', 'Samosa'})
# frozenset({'Samosa', ' Cold Coffee', 'None', ' French Fries'})
# frozenset({' Maggie', 'Tea', 'Pizza', 'Samosa'})
# frozenset({' Tea', ' Noodles', 'Samosa', ' Sandwich'})
# frozenset({'Black Tea', 'Tea', 'Cold Coffee', 'Noodles'})
# frozenset({'Fried Maggie', 'French Fries', 'Black Tea', 'None'})
# frozenset({'Fried Maggie', 'Black Tea', 'Sandwich', 'None'})
# frozenset({'Samosa', 'Manchurian', 'Black Tea', 'None'})
# frozenset({'Manchurian', 'Black Tea', 'Sandwich', 'Noodles'})
# frozenset({'Samosa', 'French Fries', 'Cold Coffee', 'None'})
# frozenset({'None', 'Cold Coffee', 'Maggie', 'Noodles'})
# frozenset({'None', 'Sandwich', 'Cold Coffee', 'Maggie'})
# frozenset({'Samosa', 'Pizza', 'Cold Coffee', 'Maggie'})
# frozenset({'Samosa', 'Sandwich', 'Cold Coffee', 'Maggie'})
# frozenset({'Samosa', 'Fried Maggie', 'Sandwich', 'None'})

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule:  Cold Coffee ->  French Fries
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Maggie -> Pizza
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 9.5
# =====================================
# Rule:  Maggie -> Tea
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 6.333333333333334
# =====================================
# Rule:  Noodles ->  Sandwich
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Tea ->  Noodles
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Tea ->  Sandwich
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule: Cold Coffee -> Maggie
# Support: 0.21052631578947367
# Confidence: 0.6666666666666666
# Lift: 3.1666666666666665
# =====================================
# Rule: Manchurian -> Noodles
# Support: 0.10526315789473684
# Confidence: 0.6666666666666666
# Lift: 3.1666666666666665
# =====================================
# Rule: Tea -> Pizza
# Support: 0.05263157894736842
# Confidence: 0.5
# Lift: 3.166666666666667
# =====================================
# Rule:  Cold Coffee -> None
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Cold Coffee -> Samosa
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Maggie -> Pizza
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 9.5
# =====================================
# Rule:  Maggie -> Tea
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Maggie -> Tea
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 9.5
# =====================================
# Rule:  Tea ->  Noodles
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Noodles -> Samosa
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Tea ->  Noodles
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Tea -> Samosa
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule: Black Tea -> Cold Coffee
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: Black Tea -> Tea
# Support: 0.05263157894736842
# Confidence: 0.3333333333333333
# Lift: 6.333333333333333
# =====================================
# Rule: Fried Maggie -> French Fries
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 3.166666666666667
# =====================================
# Rule: Manchurian -> Black Tea
# Support: 0.10526315789473684
# Confidence: 0.6666666666666666
# Lift: 4.222222222222222
# =====================================
# Rule: Manchurian -> Black Tea
# Support: 0.10526315789473684
# Confidence: 0.6666666666666666
# Lift: 4.222222222222222
# =====================================
# Rule: Black Tea -> Sandwich
# Support: 0.10526315789473684
# Confidence: 0.5
# Lift: 3.166666666666667
# =====================================
# Rule: Black Tea -> Tea
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: None -> Cold Coffee
# Support: 0.10526315789473684
# Confidence: 0.3333333333333333
# Lift: 3.1666666666666665
# =====================================
# Rule: Cold Coffee -> Maggie
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 3.166666666666667
# =====================================
# Rule: Pizza -> Cold Coffee
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: Samosa -> Cold Coffee
# Support: 0.10526315789473684
# Confidence: 0.3333333333333333
# Lift: 3.1666666666666665
# =====================================
# Rule: Sandwich -> Cold Coffee
# Support: 0.10526315789473684
# Confidence: 0.3333333333333333
# Lift: 3.1666666666666665
# =====================================
# Rule: Cold Coffee -> None
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 3.166666666666667
# =====================================
# Rule: Tea -> Cold Coffee
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: Pizza -> Cold Coffee
# Support: 0.05263157894736842
# Confidence: 0.5
# Lift: 3.166666666666667
# =====================================
# Rule: None -> Maggie
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: Samosa -> Pizza
# Support: 0.05263157894736842
# Confidence: 0.5
# Lift: 4.75
# =====================================
# Rule: Manchurian -> Sandwich
# Support: 0.10526315789473684
# Confidence: 0.6666666666666666
# Lift: 6.333333333333333
# =====================================
# Rule: Tea -> Pizza
# Support: 0.05263157894736842
# Confidence: 0.5
# Lift: 4.75
# =====================================
# Rule: Samosa ->  Cold Coffee
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Maggie -> Tea
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule:  Tea ->  Noodles
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 19.0
# =====================================
# Rule: Black Tea -> Tea
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: Fried Maggie -> French Fries
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 3.166666666666667
# =====================================
# Rule: Fried Maggie -> Black Tea
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 3.166666666666667
# =====================================
# Rule: Samosa -> Manchurian
# Support: 0.05263157894736842
# Confidence: 0.2
# Lift: 3.8000000000000003
# =====================================
# Rule: Manchurian -> Black Tea
# Support: 0.10526315789473684
# Confidence: 0.6666666666666666
# Lift: 6.333333333333333
# =====================================
# Rule: Samosa -> French Fries
# Support: 0.05263157894736842
# Confidence: 0.3333333333333333
# Lift: 6.333333333333333
# =====================================
# Rule: None -> Cold Coffee
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: None -> Sandwich
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: Samosa -> Pizza
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: Samosa -> Sandwich
# Support: 0.05263157894736842
# Confidence: 0.25
# Lift: 4.75
# =====================================
# Rule: Samosa -> Fried Maggie
# Support: 0.05263157894736842
# Confidence: 1.0
# Lift: 3.166666666666667
# =====================================
